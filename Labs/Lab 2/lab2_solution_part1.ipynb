# %%
'''
CS585 Image and Video Computing
Lab 2 Part I
--------------
This program introduces the following concepts:
a) Finding objects in a binary image
b) Filtering objects based on size
c) Obtaining information about the objects described by their contours|
--------------
'''

import cv2
import numpy as np
import matplotlib.pyplot as plt

# Global variables
thresh = 128
max_thresh = 255

# %%
# function threshold_callback 
# x receives the trackbar position value
def threshold_callback(x, img):
    print("Threshold: ", x)
    # Convert into binary image using thresholding
    # Documentation for threshold: http://docs.opencv.org/modules/imgproc/doc/miscellaneous_transformations.html?highlight=threshold#threshold
    # Example of thresholding: http://docs.opencv.org/doc/tutorials/imgproc/threshold/threshold.html
    _, thres_output = cv2.threshold(img, x, max_thresh, 0)

    # Create Window and display thresholded image
    cv2.namedWindow('Thres')
    cv2.imshow('Thres', thres_output)

    # Find contours
	# Documentation for finding contours: http://docs.opencv.org/modules/imgproc/doc/structural_analysis_and_shape_descriptors.html?highlight=findcontours#findcontours
    contours, hierarchy = cv2.findContours(thres_output, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    print("The number of contours detected is: ", len(contours))

    contour_output = cv2.cvtColor(np.zeros(np.shape(thres_output), dtype='uint8'), cv2.COLOR_GRAY2BGR)

    if (len(contours) > 0):
        # Find largest contour
        max_id = max(enumerate(contours), key=lambda x : cv2.contourArea(x[1]))[0]
        max_size = cv2.contourArea(contours[max_id])
        boundrec = cv2.boundingRect(contours[max_id])

        # Draw contours(ONLY the biggest one is drawn)
	    # Documentation for drawing contours: http://docs.opencv.org/modules/imgproc/doc/structural_analysis_and_shape_descriptors.html?highlight=drawcontours#drawcontours
        cv2.drawContours(contour_output, contours, max_id, (255, 0, 0), cv2.FILLED, 8)
        cv2.drawContours(contour_output, contours, max_id, (0, 0, 255), 2, 8)
        #cv2.drawContours(contour_output, contours, -1, (255, 0, 0), cv2.FILLED, 8)
        #cv2.drawContours(contour_output, contours, -1, (0, 0, 255), 2, 8)
        # Documentation for drawing rectangle: http://docs.opencv.org/modules/core/doc/drawing_functions.html
        cv2.rectangle(contour_output, boundrec, (0, 255, 0), 1, 8, 0)

        print("The area of the largest contour detected is: ",  cv2.contourArea(contours[max_id]))
        print("-----------------------------")

        # Show in a window
        cv2.namedWindow("Contours", cv2.WINDOW_AUTOSIZE)
        cv2.imshow("Contours", contour_output)
        #plt.figure()
        #plt_countour_output = cv2.cvtColor(contour_output, cv2.COLOR_BGR2RGB)
        #plt.imshow(contour_output)
        #plt.show()

# %%
# Load source image and convert it to gray
src = cv2.imread("hand.jpg", cv2.IMREAD_COLOR)

# Create Window and display source image
cv2.namedWindow('Source')
cv2.imshow('Source', src)

# Convert image to gray
# Documentation for cvtColor: http://docs.opencv.org/modules/imgproc/doc/miscellaneous_transformations.html
src_gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

# Blur the image
# Documentation for blur: http://docs.opencv.org/modules/imgproc/doc/filtering.html?highlight=blur#blur
src_blur = cv2.blur(src_gray, (3, 3))

# Create Trackbar
# Documentation for createTrackbar: http://docs.opencv.org/modules/highgui/doc/user_interface.html?highlight=createtrackbar#createtrackbar
# Example of adding a trackbar: http://docs.opencv.org/doc/tutorials/highgui/trackbar/trackbar.html
cv2.createTrackbar("Threshold:", "Source", thresh, max_thresh, lambda x: threshold_callback(x, src_blur))

# Wait until keypress
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Threshold:  77
# The number of contours detected is:  1
# The area of the largest contour detected is:  158266.0
# -----------------------------
# Threshold:  78
# The number of contours detected is:  1
# The area of the largest contour detected is:  158181.5
# -----------------------------
# Threshold:  79
# The number of contours detected is:  3
# The area of the largest contour detected is:  158099.0
# -----------------------------
# Threshold:  80
# The number of contours detected is:  2
# The area of the largest contour detected is:  158003.0
# -----------------------------
# Threshold:  81
# The number of contours detected is:  2
# The area of the largest contour detected is:  157910.5
# -----------------------------
# Threshold:  82
# The number of contours detected is:  2
# The area of the largest contour detected is:  157823.5
# -----------------------------
# Threshold:  83
# The number of contours detected is:  2
# The area of the largest contour detected is:  157740.5
# -----------------------------
# Threshold:  84
# The number of contours detected is:  2
# The area of the largest contour detected is:  157648.0
# -----------------------------
# Threshold:  85
# The number of contours detected is:  3
# The area of the largest contour detected is:  157550.0
# -----------------------------
# Threshold:  86
# The number of contours detected is:  2
# The area of the largest contour detected is:  157477.0
# -----------------------------
# Threshold:  87
# The number of contours detected is:  3
# The area of the largest contour detected is:  157373.5
# -----------------------------
# Threshold:  88
# The number of contours detected is:  2
# The area of the largest contour detected is:  157279.0
# -----------------------------
# Threshold:  89
# The number of contours detected is:  3
# The area of the largest contour detected is:  157179.5
# -----------------------------
# Threshold:  90
# The number of contours detected is:  3
# The area of the largest contour detected is:  157081.5
# -----------------------------
# Threshold:  91
# The number of contours detected is:  1
# The area of the largest contour detected is:  156920.5
# -----------------------------
# Threshold:  92
# The number of contours detected is:  1
# The area of the largest contour detected is:  156801.5
# -----------------------------
# Threshold:  93
# The number of contours detected is:  2
# The area of the largest contour detected is:  156669.5
# -----------------------------
# Threshold:  92
# The number of contours detected is:  1
# The area of the largest contour detected is:  156801.5
# -----------------------------
# Threshold:  91
# The number of contours detected is:  1
# The area of the largest contour detected is:  156920.5
# -----------------------------
# Threshold:  90
# The number of contours detected is:  3
# The area of the largest contour detected is:  157081.5
# -----------------------------
# Threshold:  89
# The number of contours detected is:  3
# The area of the largest contour detected is:  157179.5
# -----------------------------
# Threshold:  88
# The number of contours detected is:  2
# The area of the largest contour detected is:  157279.0
# -----------------------------
# Threshold:  87
# The number of contours detected is:  3
# The area of the largest contour detected is:  157373.5
# -----------------------------
# Threshold:  86
# The number of contours detected is:  2
# The area of the largest contour detected is:  157477.0
# -----------------------------
# Threshold:  85
# The number of contours detected is:  3
# The area of the largest contour detected is:  157550.0
# -----------------------------
# Threshold:  84
# The number of contours detected is:  2
# The area of the largest contour detected is:  157648.0
# -----------------------------
# Threshold:  83
# The number of contours detected is:  2
# The area of the largest contour detected is:  157740.5
# -----------------------------
# Threshold:  82
# The number of contours detected is:  2
# The area of the largest contour detected is:  157823.5
# -----------------------------
# Threshold:  81
# The number of contours detected is:  2
# The area of the largest contour detected is:  157910.5
# -----------------------------
# Threshold:  82
# The number of contours detected is:  2
# The area of the largest contour detected is:  157823.5
# -----------------------------
# Threshold:  83
# The number of contours detected is:  2
# The area of the largest contour detected is:  157740.5
# -----------------------------
# Threshold:  84
# The number of contours detected is:  2
# The area of the largest contour detected is:  157648.0
# -----------------------------
# Threshold:  86
# The number of contours detected is:  2
# The area of the largest contour detected is:  157477.0
# -----------------------------
# Threshold:  87
# The number of contours detected is:  3
# The area of the largest contour detected is:  157373.5
# -----------------------------
# Threshold:  88
# The number of contours detected is:  2
# The area of the largest contour detected is:  157279.0
# -----------------------------
# Threshold:  90
# The number of contours detected is:  3
# The area of the largest contour detected is:  157081.5
# -----------------------------
# Threshold:  91
# The number of contours detected is:  1
# The area of the largest contour detected is:  156920.5
# -----------------------------
# Threshold:  92
# The number of contours detected is:  1
# The area of the largest contour detected is:  156801.5
# -----------------------------
# Threshold:  93
# The number of contours detected is:  2
# The area of the largest contour detected is:  156669.5
# -----------------------------
# Threshold:  94
# The number of contours detected is:  2
# The area of the largest contour detected is:  156539.5
# -----------------------------
# Threshold:  95
# The number of contours detected is:  3
# The area of the largest contour detected is:  156402.0
# -----------------------------
# Threshold:  96
# The number of contours detected is:  3
# The area of the largest contour detected is:  156237.5
# -----------------------------
# Threshold:  97
# The number of contours detected is:  4
# The area of the largest contour detected is:  156101.5
# -----------------------------
# Threshold:  98
# The number of contours detected is:  3
# The area of the largest contour detected is:  155932.0
# -----------------------------
# Threshold:  99
# The number of contours detected is:  5
# The area of the largest contour detected is:  155767.0
# -----------------------------
# Threshold:  100
# The number of contours detected is:  4
# The area of the largest contour detected is:  155612.5
# -----------------------------
# Threshold:  101
# The number of contours detected is:  4
# The area of the largest contour detected is:  155439.0
# -----------------------------
# Threshold:  102
# The number of contours detected is:  2
# The area of the largest contour detected is:  155199.5
# -----------------------------
# Threshold:  103
# The number of contours detected is:  1
# The area of the largest contour detected is:  154880.5
# -----------------------------
# Threshold:  104
# The number of contours detected is:  3
# The area of the largest contour detected is:  154669.5
# -----------------------------
# Threshold:  105
# The number of contours detected is:  6
# The area of the largest contour detected is:  154427.5
# -----------------------------
# Threshold:  106
# The number of contours detected is:  3
# The area of the largest contour detected is:  154164.5
# -----------------------------
# Threshold:  107
# The number of contours detected is:  2
# The area of the largest contour detected is:  153862.5
# -----------------------------
# Threshold:  108
# The number of contours detected is:  2
# The area of the largest contour detected is:  153563.5
# -----------------------------
# Threshold:  109
# The number of contours detected is:  6
# The area of the largest contour detected is:  153197.5
# -----------------------------
# Threshold:  110
# The number of contours detected is:  5
# The area of the largest contour detected is:  152856.0
# -----------------------------
# Threshold:  111
# The number of contours detected is:  4
# The area of the largest contour detected is:  152489.0
# -----------------------------
# Threshold:  112
# The number of contours detected is:  2
# The area of the largest contour detected is:  152099.0
# -----------------------------
# Threshold:  113
# The number of contours detected is:  5
# The area of the largest contour detected is:  151740.5
# -----------------------------
# Threshold:  112
# The number of contours detected is:  2
# The area of the largest contour detected is:  152099.0
# -----------------------------
# Threshold:  110
# The number of contours detected is:  5
# The area of the largest contour detected is:  152856.0
# -----------------------------
# Threshold:  108
# The number of contours detected is:  2
# The area of the largest contour detected is:  153563.5
# -----------------------------
# Threshold:  106
# The number of contours detected is:  3
# The area of the largest contour detected is:  154164.5
# -----------------------------
# Threshold:  105
# The number of contours detected is:  6
# The area of the largest contour detected is:  154427.5
# -----------------------------
# Threshold:  104
# The number of contours detected is:  3
# The area of the largest contour detected is:  154669.5
# -----------------------------
# Threshold:  103
# The number of contours detected is:  1
# The area of the largest contour detected is:  154880.5
# -----------------------------
# Threshold:  102
# The number of contours detected is:  2
# The area of the largest contour detected is:  155199.5
# -----------------------------
# Threshold:  100
# The number of contours detected is:  4
# The area of the largest contour detected is:  155612.5
# -----------------------------
# Threshold:  99
# The number of contours detected is:  5
# The area of the largest contour detected is:  155767.0
# -----------------------------
# Threshold:  98
# The number of contours detected is:  3
# The area of the largest contour detected is:  155932.0
# -----------------------------
# Threshold:  97
# The number of contours detected is:  4
# The area of the largest contour detected is:  156101.5
# -----------------------------
# Threshold:  96
# The number of contours detected is:  3
# The area of the largest contour detected is:  156237.5
# -----------------------------
# Threshold:  95
# The number of contours detected is:  3
# The area of the largest contour detected is:  156402.0
# -----------------------------
# Threshold:  94
# The number of contours detected is:  2
# The area of the largest contour detected is:  156539.5
# -----------------------------
# Threshold:  93
# The number of contours detected is:  2
# The area of the largest contour detected is:  156669.5
# -----------------------------
# Threshold:  92
# The number of contours detected is:  1
# The area of the largest contour detected is:  156801.5
# -----------------------------
# Threshold:  91
# The number of contours detected is:  1
# The area of the largest contour detected is:  156920.5
# -----------------------------
# Threshold:  90
# The number of contours detected is:  3
# The area of the largest contour detected is:  157081.5
# -----------------------------
# Threshold:  89
# The number of contours detected is:  3
# The area of the largest contour detected is:  157179.5
# -----------------------------
# Threshold:  88
# The number of contours detected is:  2
# The area of the largest contour detected is:  157279.0
# -----------------------------
# Threshold:  87
# The number of contours detected is:  3
# The area of the largest contour detected is:  157373.5
# -----------------------------
# Threshold:  86
# The number of contours detected is:  2
# The area of the largest contour detected is:  157477.0
# -----------------------------
# Threshold:  85
# The number of contours detected is:  3
# The area of the largest contour detected is:  157550.0
# -----------------------------
# Threshold:  84
# The number of contours detected is:  2
# The area of the largest contour detected is:  157648.0
# -----------------------------
# Threshold:  83
# The number of contours detected is:  2
# The area of the largest contour detected is:  157740.5
# -----------------------------
# Threshold:  82
# The number of contours detected is:  2
# The area of the largest contour detected is:  157823.5
# -----------------------------
# Threshold:  83
# The number of contours detected is:  2
# The area of the largest contour detected is:  157740.5
# -----------------------------
# Threshold:  84
# The number of contours detected is:  2
# The area of the largest contour detected is:  157648.0
# -----------------------------
# Threshold:  85
# The number of contours detected is:  3
# The area of the largest contour detected is:  157550.0
# -----------------------------
# Threshold:  86
# The number of contours detected is:  2
# The area of the largest contour detected is:  157477.0
# -----------------------------
# Threshold:  87
# The number of contours detected is:  3
# The area of the largest contour detected is:  157373.5
# -----------------------------
# Threshold:  88
# The number of contours detected is:  2
# The area of the largest contour detected is:  157279.0
# -----------------------------
# Threshold:  90
# The number of contours detected is:  3
# The area of the largest contour detected is:  157081.5
# -----------------------------
# Threshold:  92
# The number of contours detected is:  1
# The area of the largest contour detected is:  156801.5
# -----------------------------
# Threshold:  93
# The number of contours detected is:  2
# The area of the largest contour detected is:  156669.5
# -----------------------------
# Threshold:  95
# The number of contours detected is:  3
# The area of the largest contour detected is:  156402.0
# -----------------------------
# Threshold:  96
# The number of contours detected is:  3
# The area of the largest contour detected is:  156237.5
# -----------------------------
# Threshold:  100
# The number of contours detected is:  4
# The area of the largest contour detected is:  155612.5
# -----------------------------
# Threshold:  102
# The number of contours detected is:  2
# The area of the largest contour detected is:  155199.5
# -----------------------------
# Threshold:  104
# The number of contours detected is:  3
# The area of the largest contour detected is:  154669.5
# -----------------------------
# Threshold:  106
# The number of contours detected is:  3
# The area of the largest contour detected is:  154164.5
# -----------------------------
# Threshold:  108
# The number of contours detected is:  2
# The area of the largest contour detected is:  153563.5
# -----------------------------
# Threshold:  109
# The number of contours detected is:  6
# The area of the largest contour detected is:  153197.5
# -----------------------------
# Threshold:  112
# The number of contours detected is:  2
# The area of the largest contour detected is:  152099.0
# -----------------------------
# Threshold:  113
# The number of contours detected is:  5
# The area of the largest contour detected is:  151740.5
# -----------------------------
# Threshold:  115
# The number of contours detected is:  5
# The area of the largest contour detected is:  150851.0
# -----------------------------
# Threshold:  117
# The number of contours detected is:  3
# The area of the largest contour detected is:  149960.5
# -----------------------------
# Threshold:  118
# The number of contours detected is:  4
# The area of the largest contour detected is:  149494.0
# -----------------------------
# Threshold:  120
# The number of contours detected is:  7
# The area of the largest contour detected is:  148417.5
# -----------------------------
# Threshold:  121
# The number of contours detected is:  6
# The area of the largest contour detected is:  147847.5
# -----------------------------
# Threshold:  123
# The number of contours detected is:  8
# The area of the largest contour detected is:  146642.0
# -----------------------------
# Threshold:  124
# The number of contours detected is:  10
# The area of the largest contour detected is:  146020.5
# -----------------------------
# Threshold:  125
# The number of contours detected is:  15
# The area of the largest contour detected is:  145338.0
# -----------------------------
# Threshold:  126
# The number of contours detected is:  17
# The area of the largest contour detected is:  144661.5
# -----------------------------
# Threshold:  127
# The number of contours detected is:  26
# The area of the largest contour detected is:  143909.5
# -----------------------------
# Threshold:  128
# The number of contours detected is:  20
# The area of the largest contour detected is:  143160.0
# -----------------------------
# Threshold:  129
# The number of contours detected is:  20
# The area of the largest contour detected is:  142412.0
# -----------------------------
# Threshold:  130
# The number of contours detected is:  26
# The area of the largest contour detected is:  141599.0
# -----------------------------
# Threshold:  131
# The number of contours detected is:  29
# The area of the largest contour detected is:  140861.5
# -----------------------------
# Threshold:  132
# The number of contours detected is:  23
# The area of the largest contour detected is:  139972.5
# -----------------------------
# Threshold:  133
# The number of contours detected is:  41
# The area of the largest contour detected is:  138995.0
# -----------------------------
# Threshold:  134
# The number of contours detected is:  37
# The area of the largest contour detected is:  137928.5
# -----------------------------
# Threshold:  135
# The number of contours detected is:  42
# The area of the largest contour detected is:  136692.0
# -----------------------------
# Threshold:  136
# The number of contours detected is:  47
# The area of the largest contour detected is:  135435.5
# -----------------------------
# Threshold:  137
# The number of contours detected is:  49
# The area of the largest contour detected is:  134162.0
# -----------------------------
# Threshold:  138
# The number of contours detected is:  48
# The area of the largest contour detected is:  129753.5
# -----------------------------
# Threshold:  140
# The number of contours detected is:  56
# The area of the largest contour detected is:  127400.5
# -----------------------------
# Threshold:  141
# The number of contours detected is:  58
# The area of the largest contour detected is:  126279.5
# -----------------------------
# Threshold:  143
# The number of contours detected is:  78
# The area of the largest contour detected is:  119719.5
# -----------------------------
# Threshold:  144
# The number of contours detected is:  75
# The area of the largest contour detected is:  118168.0
# -----------------------------
# Threshold:  145
# The number of contours detected is:  80
# The area of the largest contour detected is:  116656.0
# -----------------------------
# Threshold:  147
# The number of contours detected is:  73
# The area of the largest contour detected is:  113499.5
# -----------------------------
# Threshold:  148
# The number of contours detected is:  79
# The area of the largest contour detected is:  111734.5
# -----------------------------
# Threshold:  149
# The number of contours detected is:  98
# The area of the largest contour detected is:  109782.0
# -----------------------------
# Threshold:  151
# The number of contours detected is:  98
# The area of the largest contour detected is:  106499.0
# -----------------------------
# Threshold:  152
# The number of contours detected is:  110
# The area of the largest contour detected is:  104720.0
# -----------------------------
# Threshold:  153
# The number of contours detected is:  120
# The area of the largest contour detected is:  103004.5
# -----------------------------
# Threshold:  155
# The number of contours detected is:  130
# The area of the largest contour detected is:  98924.5
# -----------------------------
# Threshold:  157
# The number of contours detected is:  149
# The area of the largest contour detected is:  86415.0
# -----------------------------
# Threshold:  158
# The number of contours detected is:  144
# The area of the largest contour detected is:  84455.0
# -----------------------------
# Threshold:  159
# The number of contours detected is:  139
# The area of the largest contour detected is:  79450.5
# -----------------------------
# Threshold:  161
# The number of contours detected is:  168
# The area of the largest contour detected is:  75183.5
# -----------------------------
# Threshold:  162
# The number of contours detected is:  173
# The area of the largest contour detected is:  72892.0
# -----------------------------
# Threshold:  163
# The number of contours detected is:  180
# The area of the largest contour detected is:  63799.5
# -----------------------------
# Threshold:  164
# The number of contours detected is:  209
# The area of the largest contour detected is:  60241.5
# -----------------------------
# Threshold:  165
# The number of contours detected is:  191
# The area of the largest contour detected is:  57490.0
# -----------------------------
# Threshold:  166
# The number of contours detected is:  206
# The area of the largest contour detected is:  54023.5
# -----------------------------
# Threshold:  167
# The number of contours detected is:  207
# The area of the largest contour detected is:  51198.5
# -----------------------------
# Threshold:  168
# The number of contours detected is:  197
# The area of the largest contour detected is:  44999.5
# -----------------------------
# Threshold:  169
# The number of contours detected is:  200
# The area of the largest contour detected is:  40284.5
# -----------------------------
# Threshold:  170
# The number of contours detected is:  201
# The area of the largest contour detected is:  36926.0
# -----------------------------
# Threshold:  173
# The number of contours detected is:  186
# The area of the largest contour detected is:  22247.0
# -----------------------------
# Threshold:  174
# The number of contours detected is:  204
# The area of the largest contour detected is:  20215.0
# -----------------------------
# Threshold:  176
# The number of contours detected is:  181
# The area of the largest contour detected is:  17731.5
# -----------------------------
# Threshold:  177
# The number of contours detected is:  173
# The area of the largest contour detected is:  16233.0
# -----------------------------
# Threshold:  178
# The number of contours detected is:  162
# The area of the largest contour detected is:  14523.5
# -----------------------------
# Threshold:  179
# The number of contours detected is:  164
# The area of the largest contour detected is:  12866.5
# -----------------------------
# Threshold:  180
# The number of contours detected is:  140
# The area of the largest contour detected is:  4193.5
# -----------------------------
# Threshold:  181
# The number of contours detected is:  130
# The area of the largest contour detected is:  3815.0
# -----------------------------
# Threshold:  182
# The number of contours detected is:  138
# The area of the largest contour detected is:  3493.0
# -----------------------------
# Threshold:  181
# The number of contours detected is:  130
# The area of the largest contour detected is:  3815.0
# -----------------------------
# Threshold:  180
# The number of contours detected is:  140
# The area of the largest contour detected is:  4193.5
# -----------------------------
# Threshold:  179
# The number of contours detected is:  164
# The area of the largest contour detected is:  12866.5
# -----------------------------
# Threshold:  178
# The number of contours detected is:  162
# The area of the largest contour detected is:  14523.5
# -----------------------------
# Threshold:  177
# The number of contours detected is:  173
# The area of the largest contour detected is:  16233.0
# -----------------------------
# Threshold:  176
# The number of contours detected is:  181
# The area of the largest contour detected is:  17731.5
# -----------------------------
# Threshold:  175
# The number of contours detected is:  193
# The area of the largest contour detected is:  19110.0
# -----------------------------
# Threshold:  174
# The number of contours detected is:  204
# The area of the largest contour detected is:  20215.0
# -----------------------------
# Threshold:  173
# The number of contours detected is:  186
# The area of the largest contour detected is:  22247.0
# -----------------------------
# Threshold:  172
# The number of contours detected is:  210
# The area of the largest contour detected is:  24073.0
# -----------------------------
# Threshold:  171
# The number of contours detected is:  210
# The area of the largest contour detected is:  27916.0
# -----------------------------
# Threshold:  170
# The number of contours detected is:  201
# The area of the largest contour detected is:  36926.0
# -----------------------------
# Threshold:  169
# The number of contours detected is:  200
# The area of the largest contour detected is:  40284.5
# -----------------------------
# Threshold:  168
# The number of contours detected is:  197
# The area of the largest contour detected is:  44999.5
# -----------------------------
# Threshold:  167
# The number of contours detected is:  207
# The area of the largest contour detected is:  51198.5
# -----------------------------
# Threshold:  166
# The number of contours detected is:  206
# The area of the largest contour detected is:  54023.5
# -----------------------------
# Threshold:  165
# The number of contours detected is:  191
# The area of the largest contour detected is:  57490.0
# -----------------------------
# Threshold:  164
# The number of contours detected is:  209
# The area of the largest contour detected is:  60241.5
# -----------------------------
# Threshold:  163
# The number of contours detected is:  180
# The area of the largest contour detected is:  63799.5
# -----------------------------
# Threshold:  162
# The number of contours detected is:  173
# The area of the largest contour detected is:  72892.0
# -----------------------------
# Threshold:  161
# The number of contours detected is:  168
# The area of the largest contour detected is:  75183.5
# -----------------------------
# Threshold:  162
# The number of contours detected is:  173
# The area of the largest contour detected is:  72892.0
# -----------------------------
# Threshold:  163
# The number of contours detected is:  180
# The area of the largest contour detected is:  63799.5
# -----------------------------
# Threshold:  165
# The number of contours detected is:  191
# The area of the largest contour detected is:  57490.0
# -----------------------------
# Threshold:  166
# The number of contours detected is:  206
# The area of the largest contour detected is:  54023.5
# -----------------------------
# Threshold:  167
# The number of contours detected is:  207
# The area of the largest contour detected is:  51198.5
# -----------------------------
# Threshold:  168
# The number of contours detected is:  197
# The area of the largest contour detected is:  44999.5
# -----------------------------
# Threshold:  169
# The number of contours detected is:  200
# The area of the largest contour detected is:  40284.5
# -----------------------------
# Threshold:  170
# The number of contours detected is:  201
# The area of the largest contour detected is:  36926.0
# -----------------------------
# Threshold:  171
# The number of contours detected is:  210
# The area of the largest contour detected is:  27916.0
# -----------------------------
# Threshold:  172
# The number of contours detected is:  210
# The area of the largest contour detected is:  24073.0
# -----------------------------
# Threshold:  173
# The number of contours detected is:  186
# The area of the largest contour detected is:  22247.0
# -----------------------------
# Threshold:  174
# The number of contours detected is:  204
# The area of the largest contour detected is:  20215.0
# -----------------------------
# Threshold:  175
# The number of contours detected is:  193
# The area of the largest contour detected is:  19110.0
# -----------------------------
# Threshold:  176
# The number of contours detected is:  181
# The area of the largest contour detected is:  17731.5
# -----------------------------
# Threshold:  177
# The number of contours detected is:  173
# The area of the largest contour detected is:  16233.0
# -----------------------------
# Threshold:  178
# The number of contours detected is:  162
# The area of the largest contour detected is:  14523.5
# -----------------------------
# Threshold:  179
# The number of contours detected is:  164
# The area of the largest contour detected is:  12866.5
# -----------------------------
# Threshold:  180
# The number of contours detected is:  140
# The area of the largest contour detected is:  4193.5
# -----------------------------
# Threshold:  181
# The number of contours detected is:  130
# The area of the largest contour detected is:  3815.0
# -----------------------------
# Threshold:  182
# The number of contours detected is:  138
# The area of the largest contour detected is:  3493.0
# -----------------------------
# Threshold:  183
# The number of contours detected is:  117
# The area of the largest contour detected is:  3086.0
# -----------------------------
# Threshold:  184
# The number of contours detected is:  98
# The area of the largest contour detected is:  2570.5
# -----------------------------
# Threshold:  183
# The number of contours detected is:  117
# The area of the largest contour detected is:  3086.0
# -----------------------------
# Threshold:  182
# The number of contours detected is:  138
# The area of the largest contour detected is:  3493.0
# -----------------------------
# Threshold:  181
# The number of contours detected is:  130
# The area of the largest contour detected is:  3815.0
# -----------------------------
# Threshold:  180
# The number of contours detected is:  140
# The area of the largest contour detected is:  4193.5
# -----------------------------
# Threshold:  179
# The number of contours detected is:  164
# The area of the largest contour detected is:  12866.5
# -----------------------------
# Threshold:  178
# The number of contours detected is:  162
# The area of the largest contour detected is:  14523.5
# -----------------------------
# Threshold:  177
# The number of contours detected is:  173
# The area of the largest contour detected is:  16233.0
# -----------------------------
# Threshold:  176
# The number of contours detected is:  181
# The area of the largest contour detected is:  17731.5
# -----------------------------
# Threshold:  175
# The number of contours detected is:  193
# The area of the largest contour detected is:  19110.0
# -----------------------------
# Threshold:  174
# The number of contours detected is:  204
# The area of the largest contour detected is:  20215.0
# -----------------------------
# Threshold:  173
# The number of contours detected is:  186
# The area of the largest contour detected is:  22247.0
# -----------------------------
# Threshold:  172
# The number of contours detected is:  210
# The area of the largest contour detected is:  24073.0
# -----------------------------
# Threshold:  171
# The number of contours detected is:  210
# The area of the largest contour detected is:  27916.0
# -----------------------------
# Threshold:  170
# The number of contours detected is:  201
# The area of the largest contour detected is:  36926.0
# -----------------------------
# Threshold:  169
# The number of contours detected is:  200
# The area of the largest contour detected is:  40284.5
# -----------------------------
# Threshold:  168
# The number of contours detected is:  197
# The area of the largest contour detected is:  44999.5
# -----------------------------
# Threshold:  167
# The number of contours detected is:  207
# The area of the largest contour detected is:  51198.5
# -----------------------------
# Threshold:  166
# The number of contours detected is:  206
# The area of the largest contour detected is:  54023.5
# -----------------------------
# Threshold:  165
# The number of contours detected is:  191
# The area of the largest contour detected is:  57490.0
# -----------------------------
# Threshold:  164
# The number of contours detected is:  209
# The area of the largest contour detected is:  60241.5
# -----------------------------
# Threshold:  163
# The number of contours detected is:  180
# The area of the largest contour detected is:  63799.5
# -----------------------------
# Threshold:  162
# The number of contours detected is:  173
# The area of the largest contour detected is:  72892.0
# -----------------------------
# Threshold:  161
# The number of contours detected is:  168
# The area of the largest contour detected is:  75183.5
# -----------------------------
# Threshold:  160
# The number of contours detected is:  151
# The area of the largest contour detected is:  77775.0
# -----------------------------
# Threshold:  159
# The number of contours detected is:  139
# The area of the largest contour detected is:  79450.5
# -----------------------------
# Threshold:  158
# The number of contours detected is:  144
# The area of the largest contour detected is:  84455.0
# -----------------------------
# Threshold:  157
# The number of contours detected is:  149
# The area of the largest contour detected is:  86415.0
# -----------------------------
# Threshold:  156
# The number of contours detected is:  140
# The area of the largest contour detected is:  95281.0
# -----------------------------
# Threshold:  157
# The number of contours detected is:  149
# The area of the largest contour detected is:  86415.0
# -----------------------------
# Threshold:  158
# The number of contours detected is:  144
# The area of the largest contour detected is:  84455.0
# -----------------------------
# Threshold:  159
# The number of contours detected is:  139
# The area of the largest contour detected is:  79450.5
# -----------------------------
# Threshold:  160
# The number of contours detected is:  151
# The area of the largest contour detected is:  77775.0
# -----------------------------
# Threshold:  161
# The number of contours detected is:  168
# The area of the largest contour detected is:  75183.5
# -----------------------------
# Threshold:  163
# The number of contours detected is:  180
# The area of the largest contour detected is:  63799.5
# -----------------------------
# Threshold:  164
# The number of contours detected is:  209
# The area of the largest contour detected is:  60241.5
# -----------------------------
# Threshold:  165
# The number of contours detected is:  191
# The area of the largest contour detected is:  57490.0
# -----------------------------
# Threshold:  167
# The number of contours detected is:  207
# The area of the largest contour detected is:  51198.5
# -----------------------------
# Threshold:  168
# The number of contours detected is:  197
# The area of the largest contour detected is:  44999.5
# -----------------------------
# Threshold:  169
# The number of contours detected is:  200
# The area of the largest contour detected is:  40284.5
# -----------------------------
# Threshold:  170
# The number of contours detected is:  201
# The area of the largest contour detected is:  36926.0
# -----------------------------
# Threshold:  171
# The number of contours detected is:  210
# The area of the largest contour detected is:  27916.0
# -----------------------------
# Threshold:  172
# The number of contours detected is:  210
# The area of the largest contour detected is:  24073.0
# -----------------------------
# Threshold:  173
# The number of contours detected is:  186
# The area of the largest contour detected is:  22247.0
# -----------------------------
# Threshold:  174
# The number of contours detected is:  204
# The area of the largest contour detected is:  20215.0
# -----------------------------
# Threshold:  175
# The number of contours detected is:  193
# The area of the largest contour detected is:  19110.0
# -----------------------------
# Threshold:  176
# The number of contours detected is:  181
# The area of the largest contour detected is:  17731.5
# -----------------------------
# Threshold:  177
# The number of contours detected is:  173
# The area of the largest contour detected is:  16233.0
# -----------------------------
# Threshold:  178
# The number of contours detected is:  162
# The area of the largest contour detected is:  14523.5
# -----------------------------
# Threshold:  179
# The number of contours detected is:  164
# The area of the largest contour detected is:  12866.5
# -----------------------------
# Threshold:  180
# The number of contours detected is:  140
# The area of the largest contour detected is:  4193.5
# -----------------------------
# Threshold:  181
# The number of contours detected is:  130
# The area of the largest contour detected is:  3815.0
# -----------------------------
# Threshold:  182
# The number of contours detected is:  138
# The area of the largest contour detected is:  3493.0
# -----------------------------
# Threshold:  183
# The number of contours detected is:  117
# The area of the largest contour detected is:  3086.0
# -----------------------------
# Threshold:  184
# The number of contours detected is:  98
# The area of the largest contour detected is:  2570.5
# -----------------------------
# Threshold:  185
# The number of contours detected is:  84
# The area of the largest contour detected is:  2087.5
# -----------------------------
# Threshold:  186
# The number of contours detected is:  84
# The area of the largest contour detected is:  1044.0
# -----------------------------
# Threshold:  187
# The number of contours detected is:  66
# The area of the largest contour detected is:  799.5
# -----------------------------
# Threshold:  188
# The number of contours detected is:  53
# The area of the largest contour detected is:  616.0
# -----------------------------
# Threshold:  189
# The number of contours detected is:  46
# The area of the largest contour detected is:  551.0
# -----------------------------
# Threshold:  190
# The number of contours detected is:  29
# The area of the largest contour detected is:  487.5
# -----------------------------
# Threshold:  191
# The number of contours detected is:  24
# The area of the largest contour detected is:  435.5
# -----------------------------
# Threshold:  190
# The number of contours detected is:  29
# The area of the largest contour detected is:  487.5
# -----------------------------
# Threshold:  189
# The number of contours detected is:  46
# The area of the largest contour detected is:  551.0
# -----------------------------
# Threshold:  188
# The number of contours detected is:  53
# The area of the largest contour detected is:  616.0
# -----------------------------
# Threshold:  187
# The number of contours detected is:  66
# The area of the largest contour detected is:  799.5
# -----------------------------
# Threshold:  186
# The number of contours detected is:  84
# The area of the largest contour detected is:  1044.0
# -----------------------------
# Threshold:  184
# The number of contours detected is:  98
# The area of the largest contour detected is:  2570.5
# -----------------------------
# Threshold:  183
# The number of contours detected is:  117
# The area of the largest contour detected is:  3086.0
# -----------------------------
# Threshold:  182
# The number of contours detected is:  138
# The area of the largest contour detected is:  3493.0
# -----------------------------
# Threshold:  180
# The number of contours detected is:  140
# The area of the largest contour detected is:  4193.5
# -----------------------------
# Threshold:  179
# The number of contours detected is:  164
# The area of the largest contour detected is:  12866.5
# -----------------------------
# Threshold:  177
# The number of contours detected is:  173
# The area of the largest contour detected is:  16233.0
# -----------------------------
# Threshold:  176
# The number of contours detected is:  181
# The area of the largest contour detected is:  17731.5
# -----------------------------
# Threshold:  174
# The number of contours detected is:  204
# The area of the largest contour detected is:  20215.0
# -----------------------------
# Threshold:  172
# The number of contours detected is:  210
# The area of the largest contour detected is:  24073.0
# -----------------------------
# Threshold:  171
# The number of contours detected is:  210
# The area of the largest contour detected is:  27916.0
# -----------------------------
# Threshold:  170
# The number of contours detected is:  201
# The area of the largest contour detected is:  36926.0
# -----------------------------
# Threshold:  169
# The number of contours detected is:  200
# The area of the largest contour detected is:  40284.5
# -----------------------------
# Threshold:  168
# The number of contours detected is:  197
# The area of the largest contour detected is:  44999.5
# -----------------------------
# Threshold:  167
# The number of contours detected is:  207
# The area of the largest contour detected is:  51198.5
# -----------------------------
# Threshold:  165
# The number of contours detected is:  191
# The area of the largest contour detected is:  57490.0
# -----------------------------
# Threshold:  164
# The number of contours detected is:  209
# The area of the largest contour detected is:  60241.5
# -----------------------------
# Threshold:  163
# The number of contours detected is:  180
# The area of the largest contour detected is:  63799.5
# -----------------------------
# Threshold:  161
# The number of contours detected is:  168
# The area of the largest contour detected is:  75183.5
# -----------------------------
# Threshold:  160
# The number of contours detected is:  151
# The area of the largest contour detected is:  77775.0
# -----------------------------
# Threshold:  159
# The number of contours detected is:  139
# The area of the largest contour detected is:  79450.5
# -----------------------------
# Threshold:  157
# The number of contours detected is:  149
# The area of the largest contour detected is:  86415.0
# -----------------------------
# Threshold:  156
# The number of contours detected is:  140
# The area of the largest contour detected is:  95281.0
# -----------------------------
# Threshold:  155
# The number of contours detected is:  130
# The area of the largest contour detected is:  98924.5
# -----------------------------
# Threshold:  154
# The number of contours detected is:  115
# The area of the largest contour detected is:  100956.0
# -----------------------------
# Threshold:  153
# The number of contours detected is:  120
# The area of the largest contour detected is:  103004.5
# -----------------------------
# Threshold:  152
# The number of contours detected is:  110
# The area of the largest contour detected is:  104720.0
# -----------------------------
# Threshold:  151
# The number of contours detected is:  98
# The area of the largest contour detected is:  106499.0
# -----------------------------
# Threshold:  150
# The number of contours detected is:  84
# The area of the largest contour detected is:  108116.0
# -----------------------------
# Threshold:  149
# The number of contours detected is:  98
# The area of the largest contour detected is:  109782.0
# -----------------------------
# Threshold:  148
# The number of contours detected is:  79
# The area of the largest contour detected is:  111734.5
# -----------------------------
# Threshold:  147
# The number of contours detected is:  73
# The area of the largest contour detected is:  113499.5
# -----------------------------
# Threshold:  146
# The number of contours detected is:  69
# The area of the largest contour detected is:  115120.5
# -----------------------------
# Threshold:  145
# The number of contours detected is:  80
# The area of the largest contour detected is:  116656.0
# -----------------------------
# Threshold:  144
# The number of contours detected is:  75
# The area of the largest contour detected is:  118168.0
# -----------------------------
# Threshold:  143
# The number of contours detected is:  78
# The area of the largest contour detected is:  119719.5
# -----------------------------
# Threshold:  142
# The number of contours detected is:  69
# The area of the largest contour detected is:  121313.0
# -----------------------------
# Threshold:  141
# The number of contours detected is:  58
# The area of the largest contour detected is:  126279.5
# -----------------------------
# Threshold:  140
# The number of contours detected is:  56
# The area of the largest contour detected is:  127400.5
# -----------------------------
# Threshold:  139
# The number of contours detected is:  38
# The area of the largest contour detected is:  128637.0
# -----------------------------
# Threshold:  138
# The number of contours detected is:  48
# The area of the largest contour detected is:  129753.5
# -----------------------------
# Threshold:  137
# The number of contours detected is:  49
# The area of the largest contour detected is:  134162.0
# -----------------------------
# Threshold:  136
# The number of contours detected is:  47
# The area of the largest contour detected is:  135435.5
# -----------------------------
# Threshold:  135
# The number of contours detected is:  42
# The area of the largest contour detected is:  136692.0
# -----------------------------
# Threshold:  134
# The number of contours detected is:  37
# The area of the largest contour detected is:  137928.5
# -----------------------------
# Threshold:  133
# The number of contours detected is:  41
# The area of the largest contour detected is:  138995.0
# -----------------------------
# Threshold:  132
# The number of contours detected is:  23
# The area of the largest contour detected is:  139972.5
# -----------------------------
# Threshold:  131
# The number of contours detected is:  29
# The area of the largest contour detected is:  140861.5
# -----------------------------
# Threshold:  130
# The number of contours detected is:  26
# The area of the largest contour detected is:  141599.0
# -----------------------------
# Threshold:  129
# The number of contours detected is:  20
# The area of the largest contour detected is:  142412.0
# -----------------------------
# Threshold:  128
# The number of contours detected is:  20
# The area of the largest contour detected is:  143160.0
# -----------------------------
# Threshold:  127
# The number of contours detected is:  26
# The area of the largest contour detected is:  143909.5
# -----------------------------
# Threshold:  128
# The number of contours detected is:  20
# The area of the largest contour detected is:  143160.0
# -----------------------------
# Threshold:  129
# The number of contours detected is:  20
# The area of the largest contour detected is:  142412.0
# -----------------------------
# Threshold:  130
# The number of contours detected is:  26
# The area of the largest contour detected is:  141599.0
# -----------------------------
# Threshold:  131
# The number of contours detected is:  29
# The area of the largest contour detected is:  140861.5
# -----------------------------
# Threshold:  133
# The number of contours detected is:  41
# The area of the largest contour detected is:  138995.0
# -----------------------------
# Threshold:  134
# The number of contours detected is:  37
# The area of the largest contour detected is:  137928.5
# -----------------------------
# Threshold:  136
# The number of contours detected is:  47
# The area of the largest contour detected is:  135435.5
# -----------------------------
# Threshold:  138
# The number of contours detected is:  48
# The area of the largest contour detected is:  129753.5
# -----------------------------
# Threshold:  140
# The number of contours detected is:  56
# The area of the largest contour detected is:  127400.5
# -----------------------------
# Threshold:  142
# The number of contours detected is:  69
# The area of the largest contour detected is:  121313.0
# -----------------------------
# Threshold:  144
# The number of contours detected is:  75
# The area of the largest contour detected is:  118168.0
# -----------------------------
# Threshold:  146
# The number of contours detected is:  69
# The area of the largest contour detected is:  115120.5
# -----------------------------
# Threshold:  148
# The number of contours detected is:  79
# The area of the largest contour detected is:  111734.5
# -----------------------------
# Threshold:  150
# The number of contours detected is:  84
# The area of the largest contour detected is:  108116.0
# -----------------------------
# Threshold:  151
# The number of contours detected is:  98
# The area of the largest contour detected is:  106499.0
# -----------------------------
# Threshold:  153
# The number of contours detected is:  120
# The area of the largest contour detected is:  103004.5
# -----------------------------
# Threshold:  154
# The number of contours detected is:  115
# The area of the largest contour detected is:  100956.0
# -----------------------------
# Threshold:  155
# The number of contours detected is:  130
# The area of the largest contour detected is:  98924.5
# -----------------------------
# Threshold:  156
# The number of contours detected is:  140
# The area of the largest contour detected is:  95281.0
# -----------------------------
# Threshold:  157
# The number of contours detected is:  149
# The area of the largest contour detected is:  86415.0
# -----------------------------
# Threshold:  158
# The number of contours detected is:  144
# The area of the largest contour detected is:  84455.0
# -----------------------------
# Threshold:  159
# The number of contours detected is:  139
# The area of the largest contour detected is:  79450.5
# -----------------------------
# Threshold:  160
# The number of contours detected is:  151
# The area of the largest contour detected is:  77775.0
# -----------------------------
# Threshold:  161
# The number of contours detected is:  168
# The area of the largest contour detected is:  75183.5
# -----------------------------
# Threshold:  162
# The number of contours detected is:  173
# The area of the largest contour detected is:  72892.0
# -----------------------------
# Threshold:  163
# The number of contours detected is:  180
# The area of the largest contour detected is:  63799.5
# -----------------------------
# Threshold:  162
# The number of contours detected is:  173
# The area of the largest contour detected is:  72892.0
# -----------------------------
# Threshold:  161
# The number of contours detected is:  168
# The area of the largest contour detected is:  75183.5
# -----------------------------
# Threshold:  160
# The number of contours detected is:  151
# The area of the largest contour detected is:  77775.0
# -----------------------------
# Threshold:  159
# The number of contours detected is:  139
# The area of the largest contour detected is:  79450.5
# -----------------------------
# Threshold:  158
# The number of contours detected is:  144
# The area of the largest contour detected is:  84455.0
# -----------------------------
# Threshold:  157
# The number of contours detected is:  149
# The area of the largest contour detected is:  86415.0
# -----------------------------
# Threshold:  156
# The number of contours detected is:  140
# The area of the largest contour detected is:  95281.0
# -----------------------------
# Threshold:  155
# The number of contours detected is:  130
# The area of the largest contour detected is:  98924.5
# -----------------------------
# Threshold:  154
# The number of contours detected is:  115
# The area of the largest contour detected is:  100956.0
# -----------------------------
# Threshold:  153
# The number of contours detected is:  120
# The area of the largest contour detected is:  103004.5
# -----------------------------
# Threshold:  152
# The number of contours detected is:  110
# The area of the largest contour detected is:  104720.0
# -----------------------------
# Threshold:  151
# The number of contours detected is:  98
# The area of the largest contour detected is:  106499.0
# -----------------------------
# Threshold:  150
# The number of contours detected is:  84
# The area of the largest contour detected is:  108116.0
# -----------------------------
# Threshold:  149
# The number of contours detected is:  98
# The area of the largest contour detected is:  109782.0
# -----------------------------
# Threshold:  148
# The number of contours detected is:  79
# The area of the largest contour detected is:  111734.5
# -----------------------------
# Threshold:  147
# The number of contours detected is:  73
# The area of the largest contour detected is:  113499.5
# -----------------------------
# Threshold:  148
# The number of contours detected is:  79
# The area of the largest contour detected is:  111734.5
# -----------------------------
# Threshold:  149
# The number of contours detected is:  98
# The area of the largest contour detected is:  109782.0
# -----------------------------
# Threshold:  150
# The number of contours detected is:  84
# The area of the largest contour detected is:  108116.0
# -----------------------------
# Threshold:  151
# The number of contours detected is:  98
# The area of the largest contour detected is:  106499.0
# -----------------------------
# Threshold:  152
# The number of contours detected is:  110
# The area of the largest contour detected is:  104720.0
# -----------------------------
# Threshold:  153
# The number of contours detected is:  120
# The area of the largest contour detected is:  103004.5
# -----------------------------
# Threshold:  154
# The number of contours detected is:  115
# The area of the largest contour detected is:  100956.0
# -----------------------------
# Threshold:  155
# The number of contours detected is:  130
# The area of the largest contour detected is:  98924.5
# -----------------------------
# Threshold:  156
# The number of contours detected is:  140
# The area of the largest contour detected is:  95281.0
# -----------------------------
# Threshold:  157
# The number of contours detected is:  149
# The area of the largest contour detected is:  86415.0
# -----------------------------
# Threshold:  158
# The number of contours detected is:  144
# The area of the largest contour detected is:  84455.0
# -----------------------------
# Threshold:  159
# The number of contours detected is:  139
# The area of the largest contour detected is:  79450.5
# -----------------------------
# Threshold:  160
# The number of contours detected is:  151
# The area of the largest contour detected is:  77775.0
# -----------------------------
# Threshold:  161
# The number of contours detected is:  168
# The area of the largest contour detected is:  75183.5
# -----------------------------
# Threshold:  162
# The number of contours detected is:  173
# The area of the largest contour detected is:  72892.0
# -----------------------------
# Threshold:  163
# The number of contours detected is:  180
# The area of the largest contour detected is:  63799.5
# -----------------------------
